# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 경고 뜨지 않게 설정
import warnings
warnings.filterwarnings('ignore')

# 그래프 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams['axes.unicode_minus'] = False

# 데이터 전처리 알고리즘
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# 학습용과 검증용으로 나누는 함수
from sklearn.model_selection import train_test_split

# 교차 검증
# 지표를 하나만 설정할 경우
from sklearn.model_selection import cross_val_score
# 지표를 하나 이상 설정할 경우
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

# 모델의 최적의 하이퍼파라미터를 찾기 위한 도구
from sklearn.model_selection import GridSearchCV

# 평가함수
# 분류용
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

# 회귀용
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# 머신러닝 알고리즘 - 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier

# 머신러닝 알고리즘 - 회귀
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import VotingRegressor

# 차원축소
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# 군집화
from sklearn.cluster import KMeans
from sklearn.cluster import MeanShift
from sklearn.cluster import estimate_bandwidth

# ARIMA (시계열 예측)
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# 시간 측정을 위한 시간 모듈
import datetime
# 주식 정보를 읽어오기 위한 라이브러리
from pandas_datareader import data

# 형태소 백터를 생성하기 위한 라이브러리
from sklearn.feature_extraction.text import CountVectorizer
# 형태소 백터를 학습 백터로 변환한다.
from sklearn.feature_extraction.text import TfidfTransformer

# 데이터 수집
import requests
from bs4 import BeautifulSoup
import re
import time
import os
import json

# 한국어 형태소 분석
from konlpy.tag import Okt, Hannanum, Kkma, Mecab, Komoran

# 워드 클라우드를 위한 라이브러리
from collections import Counter
import pytagcloud
from IPython.display import Image

# 출력 창 청소를 위한 함수
from IPython.display import clear_output

# 저장
import pickle

# 딥러닝
import tensorflow as tf

# 딥러닝 모델 구조를 정의하는 것
from tensorflow.keras.models import Sequential
# 층구조를 정의하는 것
from tensorflow.keras.layers import Dense
# 활성화 함수를 정의하는 것
from tensorflow.keras.layers import Activation
# CNN : 커널을 통해 합성곱을 구하는 것. 이미지의 특징이 두드러 지게 처리한다.
from tensorflow.keras.layers import Conv2D
# MaxPooling : 불필요한 부분을 제거한다.
from tensorflow.keras.layers import MaxPooling2D
# Flatten : CNN과 MaxPooling을 하면 2차원으로 결과가 나오기 때문에 
# 1차원으로 변환하는 것
from tensorflow.keras.layers import Flatten
# Dropout : 이미지나 영상은 많은 은닉층을 가지고 있어야 데이터 학습 및 탐색이
# 가능하다. 은닉층이 많으면 과적합 될 우려가 있다. 이에 은닉층에 있는 노드를
# 경우에 따라 사용하지 않게 하여 과적합을 예방할 수 있다.
from tensorflow.keras.layers import Dropout

# 다중 분류를 위한 원핫 인코딩
# 결과데이터의 종류 수 만큼 결과데이터의 컬럼을 늘리는 작업
from tensorflow.keras.utils import to_categorical

# 저장된 학습 모델을 읽어온다.
from tensorflow.keras.models import load_model

# epoch마다 모델을 저장하는 함수
from tensorflow.keras.callbacks import ModelCheckpoint
# 더이상 성능 향상이 이루어지지 않는다면 조기 중단 시킬 수 있다.
from tensorflow.keras.callbacks import EarlyStopping

# 현재 프로젝트를 gpu에 할당한다.
# 컴퓨터의 GPU는 메모리를 가지고 있다.
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu가 있다면..
if len(gpus) > 0 :
    try :
        for gpu in gpus :
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e :
        print(e)
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# MNIST 데이터 
from tensorflow.keras.datasets import mnist

# %%
# seed 설정
np.random.seed(1)
tf.random.set_seed(1)

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
# 이미지 전처리(이미지의 색상 데이터를 0 ~ 1 사이로 맞춘다)
# 3차원 행렬을 4차원으로 변경한다.
# 2차원으로 되어 있는 이미지 행렬을 3차원으로 변경하는 작업
# (가로, 세로, 채널) -> 채널 - 흑백(1), 컬러(3)
# 이미지의 개수
cnt = X_train.shape[0]
# 이미지의 가로길이
w1 = X_train.shape[1]
# 이미지의 세로길이
h1 = X_train.shape[2]
# 채널
channel1 = 1

X_train = X_train.reshape(cnt, w1, h1, channel1)
# 값을 실수로 변경한다(데이터가 0 ~ 255 이므로 255로 나눠주기 위해)
X_train = X_train.astype('float64')
# 255로 나눠 0 ~ 1사이로 맞춘다.
X_train = X_train / 255

# %%
# 이미지 전처리(이미지의 색상 데이터를 0 ~ 1 사이로 맞춘다)
# 3차원 행렬을 4차원으로 변경한다.
# 2차원으로 되어 있는 이미지 행렬을 3차원으로 변경하는 작업
# (가로, 세로, 채널) -> 채널 - 흑백(1), 컬러(3)
# 이미지의 개수
cnt = X_test.shape[0]
# 이미지의 가로길이
w1 = X_test.shape[1]
# 이미지의 세로길이
h1 = X_test.shape[2]
# 채널
channel1 = 1

X_test = X_test.reshape(cnt, w1, h1, channel1)
# 값을 실수로 변경한다(데이터가 0 ~ 255 이므로 255로 나눠주기 위해)
X_test = X_test.astype('float64')
# 255로 나눠 0 ~ 1사이로 맞춘다.
X_test = X_test / 255

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# #### CNN 구성
# - Conv2d : 케라스에서 컨볼루션 레이어를 추가하는 함수
# - Maxpooling2D : 데이터 축소
# - Dropout : 은닉층의 노드를 임의로 꺼주는 것(과적합 방지)
# - Flatten : 2차원 배열을 1차원으로 변환

# %%
model = Sequential()

# 입력층 + 은닉층 : 이미지 데이터를 입력받아 합성곱을 수행한다.
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(28, 28, 1)))
model.add(Activation('relu'))

# 은닉층 : 데이터를 받아 합성곱을 구하고 MaxPooling을 수행한다.
model.add(Conv2D(64, kernel_size=(3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))
model.add(Flatten())

# 은닉층 : 최종 데이터를 모아 전달한다.
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# 출력
model.add(Dense(10))
model.add(Activation('softmax'))

# %%
# 모델 컴파일
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# activation (Activation)      (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 24, 24, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1179776
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델들이 저장될 위치
# epoch : 학습 횟수
# val_loss : 검증 데이터의 손실률
path1 = 'models/25_MNIST - CNN/{epoch}-{val_loss}.hdf5'
path2 = 'models/25_MNIST - CNN/최종.hdf5'

# 저장 콜백 설정
# save_best_only : True를 넣어주면 모니터링하는 값이 개선 되었을 경우에만
# 저장을 한다. 기본은 False 이며 False시 매번 저장을 한다.
call1 = ModelCheckpoint(filepath=path1, monitor='val_loss', 
                       save_best_only=True)

call2 = ModelCheckpoint(filepath=path2, monitor='val_loss', 
                       save_best_only=True)

# %%
# 조기 중단
# patience : 현재 평가 값이 이전 평가 값 보다 좋다고 판단될 경우 앞으로
# 몇번을 더 볼 것인가를 설정하는 부분
call3 = EarlyStopping(monitor='val_loss', patience=50)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), 
                    epochs=2000, batch_size=500, 
                    callbacks=[call1, call2, call3])
# Out:
# Epoch 1/2000
# 120/120 [==============================] - 5s 16ms/step - loss: 0.4187 - accuracy: 0.8719 - val_loss: 0.0815 - val_accuracy: 0.9760
# Epoch 2/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.1182 - accuracy: 0.9654 - val_loss: 0.0532 - val_accuracy: 0.9831
# Epoch 3/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0811 - accuracy: 0.9762 - val_loss: 0.0400 - val_accuracy: 0.9870
# Epoch 4/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0650 - accuracy: 0.9808 - val_loss: 0.0367 - val_accuracy: 0.9879
# Epoch 5/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0562 - accuracy: 0.9826 - val_loss: 0.0286 - val_accuracy: 0.9904
# Epoch 6/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0492 - accuracy: 0.9850 - val_loss: 0.0310 - val_accuracy: 0.9908
# Epoch 7/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0440 - accuracy: 0.9862 - val_loss: 0.0324 - val_accuracy: 0.9897
# Epoch 8/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0379 - accuracy: 0.9880 - val_loss: 0.0310 - val_accuracy: 0.9905
# Epoch 9/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0351 - accuracy: 0.9888 - val_loss: 0.0295 - val_accuracy: 0.9911
# Epoch 10/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0329 - accuracy: 0.9897 - val_loss: 0.0281 - val_accuracy: 0.9903
# Epoch 11/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0307 - accuracy: 0.9898 - val_loss: 0.0302 - val_accuracy: 0.9914
# Epoch 12/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0268 - accuracy: 0.9915 - val_loss: 0.0283 - val_accuracy: 0.9927
# Epoch 13/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0257 - accuracy: 0.9917 - val_loss: 0.0259 - val_accuracy: 0.9915
# Epoch 14/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0252 - accuracy: 0.9920 - val_loss: 0.0278 - val_accuracy: 0.9921
# Epoch 15/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0231 - accuracy: 0.9923 - val_loss: 0.0313 - val_accuracy: 0.9923
# Epoch 16/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0212 - accuracy: 0.9925 - val_loss: 0.0288 - val_accuracy: 0.9919
# Epoch 17/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0200 - accuracy: 0.9933 - val_loss: 0.0297 - val_accuracy: 0.9920
# Epoch 18/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0192 - accuracy: 0.9936 - val_loss: 0.0304 - val_accuracy: 0.9921
# Epoch 19/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.0273 - val_accuracy: 0.9930
# Epoch 20/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0174 - accuracy: 0.9942 - val_loss: 0.0317 - val_accuracy: 0.9919
# Epoch 21/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0165 - accuracy: 0.9944 - val_loss: 0.0285 - val_accuracy: 0.9920
# Epoch 22/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0160 - accuracy: 0.9948 - val_loss: 0.0329 - val_accuracy: 0.9917
# Epoch 23/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0161 - accuracy: 0.9948 - val_loss: 0.0271 - val_accuracy: 0.9920
# Epoch 24/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0150 - accuracy: 0.9948 - val_loss: 0.0329 - val_accuracy: 0.9921
# Epoch 25/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0155 - accuracy: 0.9948 - val_loss: 0.0283 - val_accuracy: 0.9921
# Epoch 26/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 0.0292 - val_accuracy: 0.9930
# Epoch 27/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.0277 - val_accuracy: 0.9924
# Epoch 28/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.0293 - val_accuracy: 0.9931
# Epoch 29/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0130 - accuracy: 0.9956 - val_loss: 0.0286 - val_accuracy: 0.9936
# Epoch 30/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0301 - val_accuracy: 0.9935
# Epoch 31/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.0311 - val_accuracy: 0.9924
# Epoch 32/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0315 - val_accuracy: 0.9921
# Epoch 33/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0123 - accuracy: 0.9955 - val_loss: 0.0313 - val_accuracy: 0.9923
# Epoch 34/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.0304 - val_accuracy: 0.9927
# Epoch 35/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.0305 - val_accuracy: 0.9926
# Epoch 36/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0324 - val_accuracy: 0.9931
# Epoch 37/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 0.0280 - val_accuracy: 0.9935
# Epoch 38/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0107 - accuracy: 0.9962 - val_loss: 0.0313 - val_accuracy: 0.9931
# Epoch 39/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.0315 - val_accuracy: 0.9932
# Epoch 40/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0336 - val_accuracy: 0.9928
# Epoch 41/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.0308 - val_accuracy: 0.9938
# Epoch 42/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0336 - val_accuracy: 0.9931
# Epoch 43/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.0295 - val_accuracy: 0.9933
# Epoch 44/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.0316 - val_accuracy: 0.9932
# Epoch 45/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.0318 - val_accuracy: 0.9927
# Epoch 46/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0357 - val_accuracy: 0.9938
# Epoch 47/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.0308 - val_accuracy: 0.9932
# Epoch 48/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0298 - val_accuracy: 0.9929
# Epoch 49/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.0307 - val_accuracy: 0.9937
# Epoch 50/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0097 - accuracy: 0.9964 - val_loss: 0.0334 - val_accuracy: 0.9935
# Epoch 51/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0318 - val_accuracy: 0.9934
# Epoch 52/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0354 - val_accuracy: 0.9926
# Epoch 53/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.0316 - val_accuracy: 0.9932
# Epoch 54/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0318 - val_accuracy: 0.9934
# Epoch 55/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0340 - val_accuracy: 0.9936
# Epoch 56/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0385 - val_accuracy: 0.9931
# Epoch 57/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0338 - val_accuracy: 0.9930
# Epoch 58/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0326 - val_accuracy: 0.9919
# Epoch 59/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0342 - val_accuracy: 0.9937
# Epoch 60/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0336 - val_accuracy: 0.9933
# Epoch 61/2000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0350 - val_accuracy: 0.9934
# Epoch 62/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0340 - val_accuracy: 0.9930
# Epoch 63/2000
# 120/120 [==============================] - 2s 16ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0346 - val_accuracy: 0.9929

# %%
# 오차 정도와 정확도를 그래프로 그린다.
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
